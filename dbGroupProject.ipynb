# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
file_links={'categories': 's3://2u-data-curriculum-team/dataviz-classroom/v1.1/22-big-data/categories.csv', 
            'customers': 's3://2u-data-curriculum-team/dataviz-classroom/v1.1/22-big-data/customers.csv', 
            'employee_territories': 's3://2u-data-curriculum-team/dataviz-classroom/v1.1/22-big-data/employee-territories.csv', 
            'employees': 's3://2u-data-curriculum-team/dataviz-classroom/v1.1/22-big-data/employees.csv', 
            'order_details': 's3://2u-data-curriculum-team/dataviz-classroom/v1.1/22-big-data/order-details.csv', 
            'orders': 's3://2u-data-curriculum-team/dataviz-classroom/v1.1/22-big-data/orders.csv', 
            'products': 's3://2u-data-curriculum-team/dataviz-classroom/v1.1/22-big-data/products.csv', 
            'regions': 's3://2u-data-curriculum-team/dataviz-classroom/v1.1/22-big-data/regions.csv', 
            'shippers': 's3://2u-data-curriculum-team/dataviz-classroom/v1.1/22-big-data/shippers.csv', 
            'suppliers': 's3://2u-data-curriculum-team/dataviz-classroom/v1.1/22-big-data/suppliers.csv', 
            'territories': 's3://2u-data-curriculum-team/dataviz-classroom/v1.1/22-big-data/territories.csv'}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
for (table_name, s3_path) in file_links.items():
    df = spark.read.csv(s3_path, inferSchema=True, header=True)
    df.createOrReplaceTempView(table_name)
    
spark.catalog.listTables()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: [Table(name=&#39;categories&#39;, database=None, description=None, tableType=&#39;TEMPORARY&#39;, isTemporary=True),
#  Table(name=&#39;customers&#39;, database=None, description=None, tableType=&#39;TEMPORARY&#39;, isTemporary=True),
#  Table(name=&#39;employee_territories&#39;, database=None, description=None, tableType=&#39;TEMPORARY&#39;, isTemporary=True),
#  Table(name=&#39;employees&#39;, database=None, description=None, tableType=&#39;TEMPORARY&#39;, isTemporary=True),
#  Table(name=&#39;order_details&#39;, database=None, description=None, tableType=&#39;TEMPORARY&#39;, isTemporary=True),
# ...

# %%
# Create a list of all countries to which orders have been shipped.


# How many orders have been placed in total?


# How many orders have been shipped to each country?
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %sql

select distinct ShipCountry from orders
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ShipCountry</th></tr></thead><tbody><tr><td>Sweden</td></tr><tr><td>Germany</td></tr><tr><td>France</td></tr><tr><td>Argentina</td></tr><tr><td>Belgium</td></tr><tr><td>Finland</td></tr><tr><td>Italy</td></tr><tr><td>Norway</td></tr><tr><td>Spain</td></tr><tr><td>Denmark</td></tr><tr><td>Ireland</td></tr><tr><td>Venezuela</td></tr><tr><td>USA</td></tr><tr><td>Mexico</td></tr><tr><td>UK</td></tr><tr><td>Switzerland</td></tr><tr><td>Canada</td></tr><tr><td>Brazil</td></tr><tr><td>Poland</td></tr><tr><td>Portugal</td></tr><tr><td>Austria</td></tr></tbody></table></div>

# %%
# %sql
select count(*) from orders
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>830</td></tr></tbody></table></div>

# %%
# %sql
select ShipCountry, count(*) from orders group by ShipCountry order by count(1) desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# For each product, list its product ID, product name, and the company name.


# Which 5 countries have the heaviest shipments, on average?


# Which 10 companies have placed the most orders? List the contact name of each company.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %sql

select p.ProductId, p.ProductName, s.CompanyName
from products as p
join suppliers as s
on p.SupplierId=s.SupplierID
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql 

select ShipCountry, avg(Freight)
from orders
group by ShipCountry
order by avg(Freight)
desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql

select c.CompanyName, c.ContactName, c.Phone ,count(*) as numOrders
from orders as o
join customers as c on o.CustomerID = c.CustomerID
group by c.CompanyName, c.ContactName, c.Phone
order by numOrders desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#Sort the customers by total amount spent on orders in descending order.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %sql

select c.CompanyName, sum(od.UnitPrice*od.Quantity) as Totalspending
from orders as o
join order_details as od
on o.OrderID=od.OrderID
join customers as c
on c.CustomerId = o.CustomerID
group by c.CustomerId, c.CompanyName
order by Totalspending
desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#Sort customers with a total spending greater than 20,000 in descending order.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Sort the employees by the number of orders they sold in descending order.

# How many employees account for about half of the orders? (You do not have to use SQL to answer this question. A rough estimate is sufficient.)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#List customers who have never placed an order.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#List the products with the highest level of discount in descending order
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
